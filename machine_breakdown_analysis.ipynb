# %% [markdown]
# # Machine Breakdown Analysis - Grafik Visualisasi
#
# Notebook ini membaca data dari file Excel, menghitung rata-rata persentase per periode, dan membuat grafik kombinasi bar dan line chart dengan target line 1,50%.
